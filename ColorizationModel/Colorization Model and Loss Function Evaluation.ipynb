# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorboard

import os
import cv2
import torchvision
import torchvision.transforms as transforms
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib import pyplot as plt
import skimage
from skimage import color, metrics, filters
from skimage.color import rgb2gray
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from mpl_toolkits.mplot3d import Axes3D
from datetime import datetime
import pytz
import math

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, UpSampling2D
from tensorflow.keras.utils import img_to_array, load_img
from tensorflow.core.util import event_pb2
from keras.preprocessing.image import ImageDataGenerator


import tensorboard
import warnings
warnings.filterwarnings('ignore')

# %%
# CHANGE THESE!!!
pwd = '/content/drive/MyDrive/COMP3362_Proj/'

# %%
# Parameters (Can change)
categoryTestSize = 3        # How many test data for each label
validation_percent = 0.2

# Constant Variables (Don't change)
data_dir = pwd + 'Datasets/FIDS30'
tz = pytz.timezone('Asia/Hong_Kong')
DIMENSION = (256, 256)
RESAMPLE = 3

# %% [markdown]
# # Classes

# %% [markdown]
# ## Data

# %%
class Data():
  def __init__(self, labelsToInclude=[], testSize=3):
    # Config data
    self.labelsToInclude = labelsToInclude # Empty labels means all data

    # Labels
    self.labels = []

    # Training Data
    self.trainingSize = 0
    self.trainImages = []
    self.x_train = None
    self.y_train = None

    # Test Data
    self.testSize = testSize
    self.testImages = dict()
    self.rgb_org_test = dict()
    self.gray_org_test = dict()
    self.lab_org_test = dict()
    self.l_org_test = dict()



  def loadImages(self):
    data_paths = []
    self.trainImages = []
    self.labels = []
    self.testImages = dict()

    ###################################
    ######### Load Data Paths #########
    ###################################
    print('Loading image paths...')
    print('')

    # Get data paths
    for dirname, _, filenames in os.walk(data_dir):
      for filename in filenames:
        file_path = os.path.join(dirname, filename)

        label = file_path.split('/')[-2]

        if (len(self.labelsToInclude) == 0 or label in self.labelsToInclude):
          data_paths.append((file_path, label))

    data_size = len(data_paths)

    print('Data paths loaded!')
    print('     Number of data:', data_size)
    print('')

    ###################################
    ########### Load Images ###########
    ###################################
    print('Loading images from paths...')
    print('')

    # Load and resize image
    for data_path, label in data_paths:
      image = np.asarray(Image.open(data_path))
      
      # Expand if only 2 in dimensions
      if (image.ndim==2):
        image = np.tile(image[:,:,None],3)
      
      # remove CMYK or RGBA image representation
      if (np.asarray(image).shape[2] != 3):
        continue
      
      # Resize Image
      image = Image.fromarray(image).resize(DIMENSION, resample=RESAMPLE)

      if (label not in self.testImages):
        self.testImages[label] = [np.asarray(image)]
      elif (len(self.testImages[label]) < self.testSize):
        self.testImages[label].append(np.asarray(image))
      else:
        self.trainImages.append(np.asarray(image))

      self.labels.append(label)

    # Convert to np array
    self.trainImages = np.asarray(self.trainImages)
    self.labels = np.asarray(self.labels)
    for label in self.testImages:
      self.testImages[label] = np.asarray(self.testImages[label])
    
    self.trainingSize = self.trainImages.shape[0]

    print('Images Loaded!')
    print('     Shape  of training data:', self.trainImages.shape)
    print('     Number of test data:')
    for label in self.testImages:
      print(f'       {label:10}: {len(self.testImages[label])}')

  
  def dataAugmentation(self, dataset_multiply=10, rotation_range=30, zoom_range=0.3, horizontal_flip=True):
    # Augment data
    train_augmentation = ImageDataGenerator(rotation_range=rotation_range,
                                            zoom_range=zoom_range,
                                            horizontal_flip=horizontal_flip,
                                            rescale=1./255)
    
    augmented_images = train_augmentation.flow(self.trainImages, batch_size=1)

    # Retrieve Augmented data
    trainImagesTemp = []

    i = 0
    for augmented_image in augmented_images:
      image = augmented_image[0]
      trainImagesTemp.append(image)

      i += 1
      if (i >= self.trainingSize * dataset_multiply):
        break

    self.trainImages = np.asarray(trainImagesTemp)
    self.trainingSize = len(self.trainImages)
    print('Augmented data shape:', self.trainImages.shape)
  
  def dataProcessing(self, image):
    # Change to LAB Space
    lab_image = color.rgb2lab(image)

    # Get L Space
    l_image = lab_image[:,:,0]

    # Get AB Space
    ab_image = lab_image[:,:,1:] / 100.

    return l_image, ab_image
  
  def processTrainingData(self):
    l_train = []   # L  of LAB image
    ab_train = []  # AB of LAB image

    for image in self.trainImages:
      l_image, ab_image = self.dataProcessing(image)

      l_train.append(l_image)
      ab_train.append(ab_image)

    # # Convert to np array with correct shape
    l_train = np.asarray(l_train)
    self.x_train = l_train.reshape(l_train.shape[0], l_train.shape[1], l_train.shape[2], 1)
    self.y_train = np.asarray(ab_train)

    print("Training Shape:")
    print("  Training Input  Images in L Space   :", self.x_train.shape)
    print("  Training Output Images in AB Space  :", self.y_train.shape)
    print('')
  
  def processTestData(self):
    self.rgb_org_test = dict()
    self.gray_org_test = dict()
    self.lab_org_test = dict()
    self.l_org_test = dict()

    test_augmentation = ImageDataGenerator(rescale=1./255)

    for label in self.testImages:
      rgb_list = []
      gray_list = []
      lab_list = []
      l_list = []

      test_images_label = test_augmentation.flow(self.testImages[label], batch_size=128, shuffle=False)

      for numBatch in range(len(test_images_label)):
        for image in test_images_label[numBatch]:
          rgb_image = np.asarray(image)
          gray_image = color.rgb2gray(rgb_image)
          lab_image = color.rgb2lab(rgb_image)
          l_image = lab_image[:,:,0]

          rgb_list.append(rgb_image)
          gray_list.append(gray_image)
          lab_list.append(lab_image)
          l_list.append(l_image)
      
      self.rgb_org_test[label] = np.asarray(rgb_list)
      self.gray_org_test[label] = np.asarray(gray_list)
      self.lab_org_test[label] = np.asarray(lab_list)
      
      l_list = np.asarray(l_list)
      l_list = l_list.reshape(l_list.shape[0], l_list.shape[1], l_list.shape[2], 1)
      self.l_org_test[label] = l_list
      
    labelToPrint = self.labels[0] if len(self.labels) > 0 else 'bananas'
    print(f"Testing Shape (category: {labelToPrint}):")
    print("  Resized Test Image in RGB  Space   :", self.rgb_org_test[labelToPrint].shape)
    print("  Resized Test Image in gray Space   :", self.gray_org_test[labelToPrint].shape)
    print("  Resized Test Image in LAB  Space   :", self.lab_org_test[labelToPrint].shape)
    print("  Resized Test Image in L    Space   :", self.l_org_test[labelToPrint].shape)
    print('')

  
  def checkDistribution(self, title):
    image_df = pd.DataFrame(data=self.labels, columns=['Fruit'])

    graph = image_df['Fruit'].value_counts()[:]
    graph.plot(kind='bar',figsize=(10,8))
    plt.xticks(rotation=90, fontsize=14)
    plt.yticks(rotation=0, fontsize=12)
    plt.xlabel('Fruits', fontsize=16)
    plt.ylabel('Distribution', fontsize=16)
    plt.title('title', fontsize=20)
  
  def showImage(self, imageArray, axis='on', grayscale=False):
    if (grayscale):
      plt.imshow(imageArray, cmap='gray', interpolation='nearest')
    else:
      plt.imshow(imageArray, interpolation='nearest')

    plt.axis(axis)
    plt.show()

# %% [markdown]
# ## Model

# %%
class ColorizationModel():

  def __init__(self, modelName, modelChoice='modelC', learningRate=0.002, decay=0.9, lossChoice='mse'):
    modelName = datetime.now(tz=tz).strftime("%m-%d %H:%M:%S ") + modelName
    self.modelLogDir = pwd + 'ModelLog (Kyle)/' + modelName
    self.trainedModelDir = pwd + 'TrainedModel (Kyle)/' + modelName
    self.model = None
    self.history = None
    self.tesnorboard_callback = None

    if (modelChoice == 'modelA'):
      self.model = self.ModelA()
    elif (modelChoice == 'modelB'):
      self.model = self.ModelB()
    elif (modelChoice == 'modelC'):
      self.model = self.ModelC()
    elif (modelChoice == 'modelD'):
      self.model = self.ModelD()
    else:
      print('No Such Model (Not Yet Implemented In Class?)')
      return
    if (lossChoice == 'mse'):
      loss = 'mse'
      optimizer= tf.keras.optimizers.Adam(learning_rate=learningRate, decay=decay, clipnorm=1.0)
      self.model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

    elif (lossChoice == 'NegSSIM'):
      optimizer= tf.keras.optimizers.Adam(learning_rate=learningRate, decay=decay, clipnorm=1.0)
      self.model.compile(optimizer=optimizer, loss=CustomAccuracy_NegSSIM, metrics=[CustomAccuracy_NegSSIM, 'accuracy'])

    elif (lossChoice == 'OneNegSSIM'):
      optimizer= tf.keras.optimizers.Adam(learning_rate=learningRate, decay=decay, clipnorm=1.0)
      self.model.compile(optimizer=optimizer, loss=CustomAccuracy_OneNegSSIM, metrics=[CustomAccuracy_OneNegSSIM, 'accuracy'])  
    else:
      print('No Such Loss (Not Yet Implemented In Class?)')

    self.model.summary()
    self.tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=self.modelLogDir)

    print('')
    print('Model Information:')
    print(f'Model of choice: {modelChoice}')
    print(f'Learning Rate: {learningRate}')
    print(f'Decay: {decay}')
    print(f'Loss Choice: {lossChoice}')
    print('')
    print(f'Model Log Directory     : {self.modelLogDir}')
    print(f'Trained Model Directory : {self.trainedModelDir}')
  
  def train(self, x_train, y_train, epochs, batch_size=128):
    print('Range:')
    print(f'x_train: [{x_train.min()}, {x_train.max()}]')
    print(f'y_train: [{y_train.min()}, {y_train.max()}]')
    self.history = self.model.fit(x=x_train, y=y_train, validation_split=validation_percent, epochs=epochs, batch_size=batch_size, callbacks=[self.tensorboard_callback], shuffle=True)

    self.model.save(self.trainedModelDir)

    print('\nWAIT! Saving Model...')

    print('\nTraining Finished')
    print('   Model Log saved in      :', self.modelLogDir)
    print('   Trained Model saved in  :', self.trainedModelDir)

  def ModelA(self):
    modelA = Sequential([
      # Encoder
      Conv2D(64, (3, 3), activation='relu', padding='same', strides=2, input_shape=(256, 256, 1)),
      Conv2D(128, (3, 3), activation='relu', padding='same'),
      Conv2D(128, (3,3), activation='relu', padding='same', strides=2),
      Conv2D(256, (3,3), activation='relu', padding='same'),
      Conv2D(256, (3,3), activation='relu', padding='same', strides=2),
      Conv2D(512, (3,3), activation='relu', padding='same'),

      # Decoder
      Conv2D(512, (3,3), activation='relu', padding='same'),
      Conv2D(256, (3,3), activation='relu', padding='same'),
      Conv2D(128, (3,3), activation='relu', padding='same'),
      UpSampling2D((2, 2)),
      Conv2D(64, (3,3), activation='relu', padding='same'),
      UpSampling2D((2, 2)),
      Conv2D(32, (3,3), activation='relu', padding='same'),
      Conv2D(16, (3,3), activation='relu', padding='same'),
      Conv2D(2, (3, 3), activation='relu', padding='same'),
      UpSampling2D((2, 2))
    ])
    return modelA
  
  def ModelB(self):
    modelB = Sequential([
      # Encoder
      Conv2D(64, (3, 3), activation='relu', padding='same', strides=2, input_shape=(256, 256, 1)),
      Conv2D(128, (3, 3), activation='relu', padding='same'),
      Conv2D(128, (3,3), activation='relu', padding='same', strides=2),
      Conv2D(256, (3,3), activation='relu', padding='same'),
      Conv2D(256, (3,3), activation='relu', padding='same', strides=2),
      Conv2D(512, (3,3), activation='relu', padding='same'),

      # Dilation layer
      Conv2D(512, (3,3), activation='relu', padding='same', dilation_rate=2),
      Conv2D(512, (3,3), activation='relu', padding='same', dilation_rate=2),
      Conv2D(512, (3,3), activation='relu', padding='same', dilation_rate=2),

      # Decoder
      Conv2D(256, (3,3), activation='relu', padding='same'),
      Conv2D(128, (3,3), activation='relu', padding='same'),
      UpSampling2D((2, 2)),
      Conv2D(64, (3,3), activation='relu', padding='same'),
      UpSampling2D((2, 2)),
      Conv2D(32, (3,3), activation='relu', padding='same'),
      Conv2D(16, (3,3), activation='relu', padding='same'),
      Conv2D(2, (3, 3), activation='relu', padding='same'),
      UpSampling2D((2, 2))
    ])
    return modelB
  
  def modelC(self):
    # Model C
    modelC = Sequential([
      # Encoder
      Conv2D(64, (3, 3), activation='relu', padding='same', strides=2, input_shape=(256, 256, 1)),
      Conv2D(128, (3, 3), activation='relu', padding='same'),
      Conv2D(128, (3,3), activation='relu', padding='same', strides=2),
      Conv2D(256, (3,3), activation='relu', padding='same'),
      Conv2D(256, (3,3), activation='relu', padding='same', strides=2),
      Conv2D(512, (3,3), activation='relu', padding='same'),

      # Dilation layer
      Conv2D(512, (3,3), activation='relu', padding='same', dilation_rate=2),
      Conv2D(512, (3,3), activation='relu', padding='same', dilation_rate=2),
      Conv2D(512, (3,3), activation='relu', padding='same', dilation_rate=2),
      Conv2D(512, (3,3), activation='relu', padding='same', dilation_rate=2),

      # Decoder
      Conv2D(512, (3,3), activation='relu', padding='same'),
      Conv2D(256, (3,3), activation='relu', padding='same'),
      UpSampling2D((2, 2)),
      Conv2D(128, (3,3), activation='relu', padding='same'),
      Conv2D(64, (3,3), activation='relu', padding='same'),
      UpSampling2D((2, 2)),
      Conv2D(32, (3,3), activation='relu', padding='same'),
      Conv2D(16, (3,3), activation='relu', padding='same'),
      Conv2D(2, (3, 3), activation='relu', padding='same'),
      UpSampling2D((2, 2))
    ])
    return modelC
  
  def ModelD(self):
    modelD = Sequential([
      # Encoder
      Conv2D(64, (3, 3), activation='relu', padding='same', strides=2, input_shape=(256, 256, 1)),
      Conv2D(128, (3, 3), activation='relu', padding='same'),
      Conv2D(128, (3,3), activation='relu', padding='same', strides=2),
      Conv2D(256, (3,3), activation='relu', padding='same'),
      Conv2D(256, (3,3), activation='relu', padding='same', strides=2),
      Conv2D(512, (3,3), activation='relu', padding='same'),

      # Decoder
      Conv2D(512, (3,3), activation='relu', padding='same'),
      Conv2D(256, (3,3), activation='relu', padding='same'),
      Conv2D(128, (3,3), activation='relu', padding='same'),
      UpSampling2D((2, 2)),
      Conv2D(64, (3,3), activation='relu', padding='same'),
      UpSampling2D((2, 2)),
      Conv2D(32, (3,3), activation='relu', padding='same'),
      Conv2D(16, (3,3), activation='relu', padding='same'),
      Conv2D(2, (3, 3), activation='tanh', padding='same'),
      UpSampling2D((2, 2))
    ])
    return modelD

# %% [markdown]
# ## Evaluation

# %%
class Evaluation():
  def __init__(self, needUnnormalized=False):
    self.needUnnormalized = needUnnormalized

  def showAccuracyAndLossLoad(self, modelName, trainName, validName, accuracyTitle, lossTitle, start=10, titleFontSize=18):
    event_file = pwd + 'ModelLog (Kyle)/' + modelName
    event_training = event_file + '/train/' + trainName
    event_validation = event_file + '/validation/' + validName

    training_accuracy = []
    training_loss = []
    validation_accuracy = []
    validation_loss = []
    epoch = []

    serialized_examples = tf.data.TFRecordDataset(event_training)
    for serialized_example in serialized_examples:
        event = event_pb2.Event.FromString(serialized_example.numpy())
        for value in event.summary.value:
            t = tf.make_ndarray(value.tensor)
            # print(value.tag, event.step, t, type(t)) 
            if (value.tag == 'epoch_accuracy'):
              training_accuracy.append(np.float32(t))
              epoch.append(event.step)
            elif (value.tag == 'epoch_loss'):
              training_loss.append(np.float32(t))



    serialized_examples = tf.data.TFRecordDataset(event_validation)
    for serialized_example in serialized_examples:
        event = event_pb2.Event.FromString(serialized_example.numpy())
        for value in event.summary.value:
            t = tf.make_ndarray(value.tensor)
            # print(value.tag, event.step, t, type(t))
            if (value.tag == 'epoch_accuracy'):
              validation_accuracy.append(np.float32(t))
            elif (value.tag == 'epoch_loss'):
              validation_loss.append(np.float32(t))


    plt.plot(epoch[start:], training_accuracy[start:], label = "Training")
    plt.plot(epoch[start:], validation_accuracy[start:], label = "Validation")
    plt.title(accuracyTitle, fontsize=titleFontSize)
    plt.xlabel('epochs', fontsize=14)
    plt.ylabel('accuracy', fontsize=14)
    plt.xticks(rotation=0, fontsize=12)
    plt.yticks(rotation=0, fontsize=12)
    plt.legend()
    plt.show()

    plt.plot(epoch[start:], training_loss[start:], label = "Training")
    plt.plot(epoch[start:], validation_loss[start:], label = "Validation")
    plt.title(lossTitle, fontsize=titleFontSize)
    plt.xlabel('epochs', fontsize=14)
    plt.ylabel('loss', fontsize=14)
    plt.xticks(rotation=0, fontsize=12)
    plt.yticks(rotation=0, fontsize=12)
    plt.legend()
    plt.show()

  def showAccuracyAndLoss(self, history, accuracyAllName, lossAllName, accuracyPartName, lossPartName, start=10):
    # Full Accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(accuracyAllName)
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Full Loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(lossAllName)
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # From Starting Point Accuracy
    plt.plot(history.history['accuracy'][start:])
    plt.plot(history.history['val_accuracy'][start:])
    plt.title(accuracyPartName)
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # From Starting Point Loss
    plt.plot(history.history['loss'][start:])
    plt.plot(history.history['val_loss'][start:])
    plt.title(lossPartName)
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

  def showOneImageInfo(self, i, label, data, model):
    test_image = data.l_org_test[label][i:i+1]
    model_output = model.predict(test_image, verbose=0)
    if (self.needUnnormalized):
      model_output *= 100

    # Predicted Image
    l_test_image = test_image[0]
    predicted_ab = model_output[0]
    predicted_lab = np.concatenate((l_test_image, predicted_ab),axis=2)
    predicted_rgb = color.lab2rgb(predicted_lab)

    # Original Image
    original_lab = data.lab_org_test[label][i]
    original_gray = data.gray_org_test[label][i]
    original_rgb = data.rgb_org_test[label][i]

    print('')
    print(f'Predicted value range:')
    print(f'  L  : [{l_test_image.min()}, {l_test_image.max()}]')
    print(f'  AB : [{predicted_ab.min()}, {predicted_ab.max()}]')
    print(f'  LAB: [{predicted_lab.min()}, {predicted_lab.max()}]')
    print(f'  RGB: [{predicted_rgb.min()}, {predicted_rgb.max()}]')
    print(f'Original value range:')
    print(f'  LAB: [{original_lab.min()}, {original_lab.max()}]')
    print(f'  RGB: [{original_rgb.min()}, {original_rgb.max()}]')
    print(f'  Gry: [{original_gray.min()}, {original_gray.max()}]')
    print('')

    
    self.showImage(original_gray, axis='off', grayscale=True, title='Original Gray')
    self.showImage(predicted_rgb, axis='off', title='Predicted RGB')
    self.showImage(original_rgb, axis='off', title='Original RGB')
    self.showImage(original_lab, axis='off', title='Original LAB')
    self.showImage(predicted_lab, axis='off', title='Predicted LAB')
    print('')
    print('Originial LAB Image 0 to 1')
    self.showImage(original_lab / 100.0, axis='off', title='Original LAB (Rescaled)')
    print('')
    print('Predicted LAB Image 0 to 1')
    self.showImage(predicted_lab / 100.0, axis='off', title='Predicted LAB (Rescaled)')
    print('')
    print('Original LAB 3D Graph')
    self.plotColor3DGraph(original_lab)
    print('')
    print('Predicted LAB 3D Graph')
    self.plotColor3DGraph(predicted_lab)
    print('')
    print('Original LAB 2D Graph')
    self.plotColor2DGraph(original_lab)
    print('')
    print('Predicted LAB 2D Graph')
    self.plotColor2DGraph(predicted_lab)

    self.showLABSpace(original_lab, predicted_lab)

    # plt.show()
  
  def plotColor2DGraph(self, lab_image):
    limit = 100
    y,x,z = lab_image.shape
    rgb_color = color.lab2rgb(lab_image)
    lab_image_flat = np.float32(np.reshape(lab_image, [y*x,z]))
    rgb_color_flat = np.float32(np.reshape(rgb_color, [y*x,z]))

    print(lab_image.shape)
    print(lab_image_flat.shape)
    print(f'Range: [{lab_image_flat.min()}, {lab_image_flat.max()}]')

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_xlim([-limit, limit])
    ax.set_ylim([-limit, limit])

    ax.scatter(x=lab_image_flat[:,2], y=lab_image_flat[:,1], c=rgb_color_flat)

    quiver1 = ax.quiver([0],[0],[limit],[0], color='y')
    quiver2 = ax.quiver([0],[0],[-limit],[0], color='b')
    quiver3 = ax.quiver([0],[0],[0],[limit], color='r')
    quiver4 = ax.quiver([0],[0],[0],[-limit], color='g')

    # Set labels
    ax.set_xlabel('B space')
    ax.set_ylabel('A space')

    plt.show()
  
  def plotColor3DGraph(self, lab_image):
    limit = 100
    y,x,z = lab_image.shape
    rgb_color = color.lab2rgb(lab_image)
    lab_image_flat = np.float32(np.reshape(lab_image, [y*x,z]))
    rgb_color_flat = np.float32(np.reshape(rgb_color, [y*x,z]))

    print(lab_image.shape)
    print(lab_image_flat.shape)
    print(f'Range: [{lab_image_flat.min()}, {lab_image_flat.max()}]')

    fig = plt.figure(figsize=(10, 10))
    ax = fig.gca(projection='3d')
    ax.set_xlim3d([-limit, limit])
    ax.set_ylim3d([-limit, limit])
    ax.set_zlim3d([0, limit])

    ax.scatter(xs=lab_image_flat[:,2], ys=lab_image_flat[:,1], zs=lab_image_flat[:,0], c=rgb_color_flat)

    quiver1 = ax.quiver([0],[0],[0],[limit],[0],[0], colors='y')
    quiver2 = ax.quiver([0],[0],[0],[-limit],[0],[0], colors='b')
    quiver3 = ax.quiver([0],[0],[0],[0],[limit],[0], colors='r')
    quiver4 = ax.quiver([0],[0],[0],[0],[-limit],[0], colors='g')
    quiver5 = ax.quiver([0],[0],[0],[0],[0],[limit], color='black')

    # Data for plotting plane x|y|z=0 within the domain
    tmp = np.linspace(0, limit, 8)
    x,y = np.meshgrid(tmp,tmp)
    z = 0*x

    ax.plot_surface(z,x,y, alpha=0.15, color='red')    # plot the plane x=0
    ax.plot_surface(z,-x,y, alpha=0.15, color='green')    # plot the plane x=0
    ax.plot_surface(x,z,y, alpha=0.15, color='yellow')  # plot the plane y=0
    ax.plot_surface(-x,z,y, alpha=0.15, color='blue')  # plot the plane y=0

    

    # Set labels at the 3d box/frame
    ax.set_xlabel('B space')
    ax.set_ylabel('A space')
    ax.set_zlabel('L space')

    plt.show()

  
  def showLABSpace(self, original_lab, predicted_lab):
    top = cm.get_cmap('Greens_r', 128)
    bottom = cm.get_cmap('Reds', 128)
    newcolors = np.vstack((top(np.linspace(0, 1, 128)),
                          bottom(np.linspace(0, 1, 128))))
    redGreenCmap = ListedColormap(newcolors, name='RedGreen')

    # top = cm.get_cmap('Blues_r', 128)
    # bottom = cm.get_cmap('Yellows', 128)
    # newcolors = np.vstack((top(np.linspace(0, 1, 128)),
    #                       bottom(np.linspace(0, 1, 128))))
    # yellowBlueCmap = ListedColormap(newcolors, name='YellowBlue')

    count = 1
    fig = plt.figure(figsize=(10,3*2))
        
    # Original
    ax = fig.add_subplot(2,3,count)
    lab_rgb_gray = original_lab[:,:,0]
    ax.imshow(lab_rgb_gray, cmap='Greys')
    ax.axis("off")
    ax.set_title("Original L: Lightness")
    count += 1
    
    ax = fig.add_subplot(2,3,count)
    lab_rgb_gray = original_lab[:,:,1]
    ax.imshow(lab_rgb_gray, cmap=redGreenCmap)
    ax.axis("off")
    ax.set_title("Original A: green to red")
    count += 1

    ax = fig.add_subplot(2,3,count)
    lab_rgb_gray = original_lab[:,:,2]
    ax.imshow(lab_rgb_gray, cmap='YlGnBu_r')
    ax.axis("off")
    ax.set_title("Original B: blue to yellow")
    count += 1

    # Predicted
    ax = fig.add_subplot(2,3,count)
    lab_rgb_gray = predicted_lab[:,:,0]
    ax.imshow(lab_rgb_gray, cmap='Greys')
    ax.axis("off")
    ax.set_title("Predicted L: lightness")
    count += 1
    
    ax = fig.add_subplot(2,3,count)
    lab_rgb_gray = predicted_lab[:,:,1]
    ax.imshow(lab_rgb_gray, cmap=redGreenCmap)
    ax.axis("off")
    ax.set_title("Predicted A: green to red")
    count += 1

    ax = fig.add_subplot(2,3,count)
    lab_rgb_gray = predicted_lab[:,:,2]
    ax.imshow(lab_rgb_gray, cmap='YlGnBu_r')
    ax.axis("off")
    ax.set_title("Predicted B: blue to yellow")
    count += 1
    
    plt.show()

  def showAllImages(self, data, model, dataStart, numOfData=1, maxSize=1000):
    plt.figure(figsize=(20,20))

    size = len(data.rgb_org_test) * numOfData
    print("Number of labels:", size)

    count = 0
    for i in range(dataStart, dataStart + numOfData):
      for label in data.rgb_org_test:
        # Use the Model
        test_image = data.l_org_test[label][i:i+1]
        model_output = model.predict(test_image, verbose=0)
        if (self.needUnnormalized):
          model_output *= 100

        # Predicted Image
        l_test_image = test_image[0]
        predicted_ab = model_output[0]
        predicted_lab = np.concatenate((l_test_image, predicted_ab),axis=2)
        predicted_rgb = color.lab2rgb(predicted_lab)

        # Original Image
        original_lab = data.lab_org_test[label][i]
        original_gray = data.gray_org_test[label][i]
        original_rgb = data.rgb_org_test[label][i]

        plt.subplot(size, 5, count*5+1)
        plt.imshow(original_lab, interpolation='nearest')
        plt.axis('off')
        plt.title('Original LAB (' + label.capitalize() + ' ' + str(i) + ')')

        plt.subplot(size, 5, count*5+2)
        plt.imshow(predicted_lab, interpolation='nearest')
        plt.axis('off')
        plt.title('Colorized LAB (' + label.capitalize() + ' ' + str(i) + ')')

        plt.subplot(size, 5, count*5+3)
        plt.imshow(original_gray, interpolation='nearest', cmap='gray')
        plt.axis('off')
        plt.title('Original Grayscale (' + label.capitalize() + ' ' + str(i) + ')')

        plt.subplot(size, 5, count*5+4)
        plt.imshow(predicted_rgb, interpolation='nearest')
        plt.axis('off')
        plt.title('Colorized RGB (' + label.capitalize() + ' ' + str(i) + ')')

        plt.subplot(size, 5, count*5+5)
        plt.imshow(original_rgb, interpolation='nearest')
        plt.axis('off')
        plt.title('Original RGB (' + label.capitalize() + ' ' + str(i) + ')')

        count += 1
        if (count == maxSize):
          break
      if (count == maxSize):
        break

    plt.show()
  
  def evaluateMetrics(self, data, model, dataStart, numOfData=1, maxSize=100):
    runningPsnr = []
    runningSsim = []
    runningUiqm = []
    runningUciqe = []

    count = 0
    for i in range(dataStart, dataStart + numOfData):
      for label in data.rgb_org_test:
        # Use the Model
        test_image = data.l_org_test[label][i:i+1]
        model_output = model.predict(test_image, verbose=0)
        if (self.needUnnormalized):
          model_output *= 100

        # Predicted Image
        l_test_image = test_image[0]
        predicted_ab = model_output[0]
        predicted_lab = np.concatenate((l_test_image, predicted_ab),axis=2)
        predicted_rgb = color.lab2rgb(predicted_lab)

        # Original Image
        original_rgb = data.rgb_org_test[label][i]

        psnr, ssim, uiqm, uciqe = self.evaluate(predicted_rgb, original_rgb)
        print(f"{label:10}({i:02}) ------PSNR = {psnr:3.6f}, SSIM = {ssim:3.6f}, UIQM = {uiqm:3.6f}, UCIQE = {uciqe:3.6f}------")

        runningPsnr.append(psnr)
        runningSsim.append(ssim)
        runningUiqm.append(uiqm)
        runningUciqe.append(uciqe)

        count += 1
        if (count == maxSize):
          break
      if (count == maxSize):
        break
      
      averagePsnr = sum(runningPsnr) / len(runningPsnr)
      averageSsim = sum(runningSsim) / len(runningSsim)
      averageUiqm = sum(runningUiqm) / len(runningUiqm)
      averageUciqe = sum(runningUciqe) / len(runningUciqe)

    print(f"-------------------------------------------------------------------------------------------------")
    print(f"{'Average':14} ------PSNR = {averagePsnr:3.6f}, SSIM = {averageSsim:3.6f}, UIQM = {averageUiqm:3.6f}, UCIQE = {averageUciqe:3.6f}------")
      


  def evaluate(self, predicted_image, original_image):
    def rmetrics(a, b):

      # pnsr
      mse = np.mean((a-b)**2)
      psnr = 10*math.log10(1/mse)

      # ssim
      ssim = metrics.structural_similarity(a, b, multichannel=True)

      return psnr, ssim


    def nmetrics(a):
      rgb = a
      lab = color.rgb2lab(a)
      gray = color.rgb2gray(a)
      # UCIQE
      c1 = 0.4680
      c2 = 0.2745
      c3 = 0.2576
      l = lab[:, :, 0]

      # 1st term
      chroma = (lab[:, :, 1]**2 + lab[:, :, 2]**2)**0.5
      uc = np.mean(chroma)
      sc = (np.mean((chroma - uc)**2))**0.5

      # 2nd term
      top = int(np.round(0.01*l.shape[0]*l.shape[1]))
      sl = np.sort(l, axis=None)
      isl = sl[::-1]
      conl = np.mean(isl[:top])-np.mean(sl[:top])

      # 3rd term
      satur = []
      chroma1 = chroma.flatten()
      l1 = l.flatten()
      for i in range(len(l1)):
        if chroma1[i] == 0:
          satur.append(0)
        elif l1[i] == 0:
          satur.append(0)
        else:
          satur.append(chroma1[i] / l1[i])

      us = np.mean(satur)

      uciqe = c1 * sc + c2 * conl + c3 * us

      # UIQM
      p1 = 0.0282
      p2 = 0.2953
      p3 = 3.5753

      # 1st term UICM
      rg = rgb[:, :, 0] - rgb[:, :, 1]
      yb = (rgb[:, :, 0] + rgb[:, :, 1]) / 2 - rgb[:, :, 2]
      rgl = np.sort(rg, axis=None)
      ybl = np.sort(yb, axis=None)
      al1 = 0.1
      al2 = 0.1
      T1 = int(al1 * len(rgl))
      T2 = int(al2 * len(rgl))
      rgl_tr = rgl[T1:-T2]
      ybl_tr = ybl[T1:-T2]

      urg = np.mean(rgl_tr)
      s2rg = np.mean((rgl_tr - urg) ** 2)
      uyb = np.mean(ybl_tr)
      s2yb = np.mean((ybl_tr - uyb) ** 2)

      uicm = -0.0268 * np.sqrt(urg**2 + uyb**2) + 0.1586 * np.sqrt(s2rg + s2yb)

      # 2nd term UISM (k1k2=8x8)
      Rsobel = rgb[:, :, 0] * filters.sobel(rgb[:, :, 0])
      Gsobel = rgb[:, :, 1] * filters.sobel(rgb[:, :, 1])
      Bsobel = rgb[:, :, 2] * filters.sobel(rgb[:, :, 2])

      Rsobel = np.round(Rsobel).astype(np.uint8)
      Gsobel = np.round(Gsobel).astype(np.uint8)
      Bsobel = np.round(Bsobel).astype(np.uint8)

      Reme = eme(Rsobel)
      Geme = eme(Gsobel)
      Beme = eme(Bsobel)

      uism = 0.299 * Reme + 0.587 * Geme + 0.114 * Beme

      # 3rd term UIConM
      uiconm = logamee(gray)

      uiqm = p1 * uicm + p2 * uism + p3 * uiconm
      return uiqm, uciqe


    def eme(ch, blocksize=8):
      num_x = math.ceil(ch.shape[0] / blocksize)
      num_y = math.ceil(ch.shape[1] / blocksize)

      eme = 0
      w = 2. / (num_x * num_y)
      for i in range(num_x):
        xlb = i * blocksize
        if i < num_x - 1:
          xrb = (i+1) * blocksize
        else:
          xrb = ch.shape[0]

        for j in range(num_y):
          ylb = j * blocksize
          if j < num_y - 1:
            yrb = (j+1) * blocksize
          else:
            yrb = ch.shape[1]

          block = ch[xlb:xrb, ylb:yrb]

          blockmin = float(np.min(block))
          blockmax = float(np.max(block))

          # # old version
          # if blockmin == 0.0: eme += 0
          # elif blockmax == 0.0: eme += 0
          # else: eme += w * math.log(blockmax / blockmin)

          # new version
          if blockmin == 0:
            blockmin += 1
          if blockmax == 0:
            blockmax += 1
          eme += w * math.log(blockmax / blockmin)
      return eme


    def plipsum(i, j, gamma=1026):
      return i + j - i * j / gamma


    def plipsub(i, j, k=1026):
      return k * (i - j) / (k - j)


    def plipmult(c, j, gamma=1026):
      return gamma - gamma * (1 - j / gamma)**c


    def logamee(ch, blocksize=8):

      num_x = math.ceil(ch.shape[0] / blocksize)
      num_y = math.ceil(ch.shape[1] / blocksize)

      s = 0
      w = 1. / (num_x * num_y)
      for i in range(num_x):
        xlb = i * blocksize

        if i < num_x - 1:
          xrb = (i+1) * blocksize
        else:
          xrb = ch.shape[0]

        for j in range(num_y):
          ylb = j * blocksize

          if j < num_y - 1:
            yrb = (j+1) * blocksize
          else:
            yrb = ch.shape[1]

          block = ch[xlb:xrb, ylb:yrb]
          blockmin = float(np.min(block))
          blockmax = float(np.max(block))

          top = plipsub(blockmax, blockmin)
          bottom = plipsum(blockmax, blockmin)

          m = top/bottom
          if m == 0.:
            s += 0
          else:
            s += (m) * np.log(m)

      return plipmult(w, s)

    psnr, ssim = rmetrics(predicted_image, original_image)
    uiqm, uciqe = nmetrics(predicted_image)
    return psnr, ssim, uiqm, uciqe

  def showImage(self, imageArray, axis='on', grayscale=False, title=''):
    if (title != ''):
      plt.title(title)
    
    if (grayscale):
      plt.imshow(imageArray, cmap='gray', interpolation='nearest')
    else:
      plt.imshow(imageArray, interpolation='nearest')

    plt.axis(axis)
    plt.show()

# %% [markdown]
# #ExperimentA
# Loss function changed from 1-SSIM

# %%
#Preparation for ExpA
labelsToInclude = ['acerolas', 'apples', 'apricots', 'avocados', 'bananas'] # Set empty list if want to test all labels
data = Data(labelsToInclude=labelsToInclude, testSize=categoryTestSize)
data.loadImages()
data.processTrainingData()
data.processTestData()
modelName = 'Model D (5 Fruits) (1000 Epochs) (0.002 lr) (Loss Function = OneNegSSIM)'
modelChoice = 'modelD'   # Currently have modelA, modelB, modelC and modelD
epochs = 1000
learningRate = 0.002
decay = 0.9
lossChoice = 'OneNegSSIM'
# Out:
# Loading image paths...
#
# Data paths loaded!
#      Number of data: 270
#
# Loading images from paths...
#
# Images Loaded!
#      Shape  of training data: (252, 256, 256, 3)
#      Number of test data:
#        bananas   : 3
#        avocados  : 3
#        acerolas  : 3
#        apples    : 3
#        apricots  : 3
# Training Shape:
#   Training Input  Images in L Space   : (252, 256, 256, 1)
#   Training Output Images in AB Space  : (252, 256, 256, 2)
#
# Testing Shape (category: bananas):
#   Resized Test Image in RGB  Space   : (3, 256, 256, 3)
#   Resized Test Image in gray Space   : (3, 256, 256)
#   Resized Test Image in LAB  Space   : (3, 256, 256, 3)
#   Resized Test Image in L    Space   : (3, 256, 256, 1)

# %%
def normalizer(x,max,min):
  a = tf.math.divide(tf.math.subtract(x, min), tf.math.subtract(max, min))
  return a

def CustomAccuracy_OneNegSSIM(y_true, y_pred):
    '''
    range of y_pred = [-1,1]
    shape of y_pred = [None, 256, 256, 2]
    range of y_true = [-1,1]
    shape of y_true = [None, 256, 256, 2]

    Step to calculate SSIM:
    1. remove the batch layer
    2. Cast the data type of y_true from integer to float32
    3. unstack y_true, which is the actual image in L-AB color space to obtain the grayscale for y_pred
    4. Normalize the value of 
    5. expand the dimension to fit the format requirement of the ssim function
    6. return the negative value of ssim function; It is because most similar images have the value of 1. 
       Putting it in the context of loss function, which aim to minimize the parameters, it has to be -1*SSIM
    7. Return it back to the model
    '''
    y_true = y_true[-1,:,:,:]
    y_pred = y_pred[-1,:,:,:]
    y_true = tf.cast(y_true, tf.float32)
    min = tf.math.minimum(tf.reduce_min(y_pred), tf.reduce_min(y_true))
    max = tf.math.maximum(tf.reduce_max(y_pred), tf.reduce_max(y_true))
    y_pred = normalizer(y_pred,max,min)
    y_true = normalizer(y_true,max,min)
    y_true = tf.expand_dims(y_true, axis = 0)
    y_pred = tf.expand_dims(y_pred, axis = 0)
    loss = tf.image.ssim(y_true, y_pred, 2.0)
    return 1 - loss

# %%
#Experiment C: change the loss function of model D to 1-ssim
def experimentC():

  colorizationModel = ColorizationModel(modelName, modelChoice=modelChoice, learningRate=learningRate, decay=decay, lossChoice=lossChoice)

  colorizationModel.train(data.x_train, data.y_train, 1000)## last parameter should be epoch

  evaluation = Evaluation()

  dataStart = 0
  numOfData = categoryTestSize
  evaluation.evaluateMetrics(data, colorizationModel.model, dataStart, numOfData)

  evaluation.showAccuracyAndLoss(colorizationModel.history, 'Model Accuracy', 'Model Loss', 'Model Accuracy from Epoch 5', 'Model Loss from Epoch 5', 5)

  evaluation.showAllImages(data, colorizationModel.model, dataStart, 1)

  evaluation.showOneImageInfo(2, 'apricots', data, colorizationModel.model)

experimentC()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_39 (Conv2D)          (None, 128, 128, 64)      640
#
#  conv2d_40 (Conv2D)          (None, 128, 128, 128)     73856
#
#  conv2d_41 (Conv2D)          (None, 64, 64, 128)       147584
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 256)       295168
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 256)       590080
#
#  conv2d_44 (Conv2D)          (None, 32, 32, 512)       1180160
#
#  conv2d_45 (Conv2D)          (None, 32, 32, 512)       2359808
#
#  conv2d_46 (Conv2D)          (None, 32, 32, 256)       1179904
#
#  conv2d_47 (Conv2D)          (None, 32, 32, 128)       295040
#
#  up_sampling2d_9 (UpSampling  (None, 64, 64, 128)      0
#  2D)
#
#  conv2d_48 (Conv2D)          (None, 64, 64, 64)        73792
#
#  up_sampling2d_10 (UpSamplin  (None, 128, 128, 64)     0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 32)      18464
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 16)      4624
#
#  conv2d_51 (Conv2D)          (None, 128, 128, 2)       290
#
#  up_sampling2d_11 (UpSamplin  (None, 256, 256, 2)      0
#  g2D)
#
# =================================================================
# Total params: 6,219,410
# Trainable params: 6,219,410
# Non-trainable params: 0
# _________________________________________________________________
#
# Model Information:
# Model of choice: modelD
# Learning Rate: 0.002
# Decay: 0.9
# Loss Choice: OneNegSSIM
#
# Model Log Directory     : /content/drive/MyDrive/COMP3362_Proj/ModelLog (Alex)/11-20 21:02:46 Model D (5 Fruits) (1000 Epochs) (0.002 lr) (Loss Function = OneNegSSIM)
# Trained Model Directory : /content/drive/MyDrive/COMP3362_Proj/TrainedModel (Alex)/11-20 21:02:46 Model D (5 Fruits) (1000 Epochs) (0.002 lr) (Loss Function = OneNegSSIM)
# Range:
# x_train: [0.0, 100.0]
# y_train: [-0.737368002052462, 0.9390017393826549]
# Epoch 1/1000
# 2/2 [==============================] - 6s 2s/step - loss: 0.4464 - CustomAccuracy_OneNegSSIM: 0.4771 - accuracy: 0.7379 - val_loss: 0.5887 - val_CustomAccuracy_OneNegSSIM: 0.5887 - val_accuracy: 0.8408
# Epoch 2/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6001 - CustomAccuracy_OneNegSSIM: 0.6001 - accuracy: 0.7418 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8410
# Epoch 3/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5836 - CustomAccuracy_OneNegSSIM: 0.5864 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8410
# Epoch 4/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6181 - CustomAccuracy_OneNegSSIM: 0.6245 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 5/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5943 - CustomAccuracy_OneNegSSIM: 0.5953 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 6/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6231 - CustomAccuracy_OneNegSSIM: 0.6196 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 7/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5940 - CustomAccuracy_OneNegSSIM: 0.5914 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 8/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6053 - CustomAccuracy_OneNegSSIM: 0.6023 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 9/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6021 - CustomAccuracy_OneNegSSIM: 0.5999 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 10/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5967 - CustomAccuracy_OneNegSSIM: 0.5973 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 11/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5792 - CustomAccuracy_OneNegSSIM: 0.5730 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 12/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5921 - CustomAccuracy_OneNegSSIM: 0.5947 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 13/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6061 - CustomAccuracy_OneNegSSIM: 0.6083 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 14/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6077 - CustomAccuracy_OneNegSSIM: 0.6045 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 15/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5858 - CustomAccuracy_OneNegSSIM: 0.5834 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 16/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5905 - CustomAccuracy_OneNegSSIM: 0.5946 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 17/1000
# 2/2 [==============================] - 2s 993ms/step - loss: 0.5884 - CustomAccuracy_OneNegSSIM: 0.5874 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 18/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6011 - CustomAccuracy_OneNegSSIM: 0.5996 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 19/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5874 - CustomAccuracy_OneNegSSIM: 0.5932 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 20/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5925 - CustomAccuracy_OneNegSSIM: 0.5929 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 21/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5986 - CustomAccuracy_OneNegSSIM: 0.5950 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 22/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5970 - CustomAccuracy_OneNegSSIM: 0.6008 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 23/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6102 - CustomAccuracy_OneNegSSIM: 0.6110 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 24/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6043 - CustomAccuracy_OneNegSSIM: 0.6065 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 25/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6184 - CustomAccuracy_OneNegSSIM: 0.6214 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 26/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5961 - CustomAccuracy_OneNegSSIM: 0.5962 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 27/1000
# 2/2 [==============================] - 2s 994ms/step - loss: 0.6067 - CustomAccuracy_OneNegSSIM: 0.6166 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 28/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5761 - CustomAccuracy_OneNegSSIM: 0.5777 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 29/1000
# 2/2 [==============================] - 2s 995ms/step - loss: 0.6302 - CustomAccuracy_OneNegSSIM: 0.6234 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 30/1000
# 2/2 [==============================] - 2s 993ms/step - loss: 0.6049 - CustomAccuracy_OneNegSSIM: 0.6067 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 31/1000
# 2/2 [==============================] - 2s 998ms/step - loss: 0.5836 - CustomAccuracy_OneNegSSIM: 0.5829 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 32/1000
# 2/2 [==============================] - 2s 994ms/step - loss: 0.5767 - CustomAccuracy_OneNegSSIM: 0.5785 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 33/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6189 - CustomAccuracy_OneNegSSIM: 0.6261 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 34/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5982 - CustomAccuracy_OneNegSSIM: 0.5987 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 35/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5843 - CustomAccuracy_OneNegSSIM: 0.5838 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 36/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5794 - CustomAccuracy_OneNegSSIM: 0.5797 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 37/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5941 - CustomAccuracy_OneNegSSIM: 0.5945 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 38/1000
# 2/2 [==============================] - 2s 991ms/step - loss: 0.6180 - CustomAccuracy_OneNegSSIM: 0.6244 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 39/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5958 - CustomAccuracy_OneNegSSIM: 0.5968 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 40/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6086 - CustomAccuracy_OneNegSSIM: 0.6042 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 41/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5897 - CustomAccuracy_OneNegSSIM: 0.5880 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 42/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6060 - CustomAccuracy_OneNegSSIM: 0.6024 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 43/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6426 - CustomAccuracy_OneNegSSIM: 0.6464 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 44/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6218 - CustomAccuracy_OneNegSSIM: 0.6219 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 45/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5914 - CustomAccuracy_OneNegSSIM: 0.5924 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 46/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5966 - CustomAccuracy_OneNegSSIM: 0.5966 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 47/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5669 - CustomAccuracy_OneNegSSIM: 0.5730 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 48/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6086 - CustomAccuracy_OneNegSSIM: 0.6082 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 49/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5852 - CustomAccuracy_OneNegSSIM: 0.5865 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 50/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6020 - CustomAccuracy_OneNegSSIM: 0.5984 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 51/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5897 - CustomAccuracy_OneNegSSIM: 0.5877 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 52/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5988 - CustomAccuracy_OneNegSSIM: 0.5987 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 53/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5934 - CustomAccuracy_OneNegSSIM: 0.5929 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 54/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5739 - CustomAccuracy_OneNegSSIM: 0.5707 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 55/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5997 - CustomAccuracy_OneNegSSIM: 0.5981 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 56/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5900 - CustomAccuracy_OneNegSSIM: 0.5883 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 57/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5821 - CustomAccuracy_OneNegSSIM: 0.5908 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 58/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6294 - CustomAccuracy_OneNegSSIM: 0.6231 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 59/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5586 - CustomAccuracy_OneNegSSIM: 0.5656 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 60/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6481 - CustomAccuracy_OneNegSSIM: 0.6464 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 61/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5881 - CustomAccuracy_OneNegSSIM: 0.5838 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 62/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5931 - CustomAccuracy_OneNegSSIM: 0.5934 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 63/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5940 - CustomAccuracy_OneNegSSIM: 0.5984 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 64/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6573 - CustomAccuracy_OneNegSSIM: 0.6458 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 65/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5989 - CustomAccuracy_OneNegSSIM: 0.6019 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 66/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6250 - CustomAccuracy_OneNegSSIM: 0.6210 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 67/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6078 - CustomAccuracy_OneNegSSIM: 0.6075 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 68/1000
# 2/2 [==============================] - 2s 996ms/step - loss: 0.5959 - CustomAccuracy_OneNegSSIM: 0.5966 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 69/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5947 - CustomAccuracy_OneNegSSIM: 0.5961 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 70/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5738 - CustomAccuracy_OneNegSSIM: 0.5759 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 71/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6071 - CustomAccuracy_OneNegSSIM: 0.6043 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 72/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6237 - CustomAccuracy_OneNegSSIM: 0.6384 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 73/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6162 - CustomAccuracy_OneNegSSIM: 0.6219 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 74/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5924 - CustomAccuracy_OneNegSSIM: 0.5928 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 75/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5919 - CustomAccuracy_OneNegSSIM: 0.5942 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 76/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5930 - CustomAccuracy_OneNegSSIM: 0.5948 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 77/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6140 - CustomAccuracy_OneNegSSIM: 0.6144 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 78/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5995 - CustomAccuracy_OneNegSSIM: 0.6000 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 79/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5875 - CustomAccuracy_OneNegSSIM: 0.5862 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 80/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5914 - CustomAccuracy_OneNegSSIM: 0.5898 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 81/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5831 - CustomAccuracy_OneNegSSIM: 0.5873 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 82/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5945 - CustomAccuracy_OneNegSSIM: 0.5940 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 83/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5732 - CustomAccuracy_OneNegSSIM: 0.5785 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 84/1000
# 2/2 [==============================] - 2s 993ms/step - loss: 0.6063 - CustomAccuracy_OneNegSSIM: 0.6126 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 85/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5973 - CustomAccuracy_OneNegSSIM: 0.5963 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 86/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5959 - CustomAccuracy_OneNegSSIM: 0.5949 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 87/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5928 - CustomAccuracy_OneNegSSIM: 0.5930 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 88/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6182 - CustomAccuracy_OneNegSSIM: 0.6187 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 89/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5998 - CustomAccuracy_OneNegSSIM: 0.6027 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 90/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6340 - CustomAccuracy_OneNegSSIM: 0.6465 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 91/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5839 - CustomAccuracy_OneNegSSIM: 0.5859 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 92/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6366 - CustomAccuracy_OneNegSSIM: 0.6277 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 93/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6330 - CustomAccuracy_OneNegSSIM: 0.6448 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 94/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6486 - CustomAccuracy_OneNegSSIM: 0.6367 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 95/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5893 - CustomAccuracy_OneNegSSIM: 0.5874 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 96/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6016 - CustomAccuracy_OneNegSSIM: 0.6024 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 97/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6063 - CustomAccuracy_OneNegSSIM: 0.6050 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 98/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5931 - CustomAccuracy_OneNegSSIM: 0.5975 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 99/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6347 - CustomAccuracy_OneNegSSIM: 0.6326 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 100/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6421 - CustomAccuracy_OneNegSSIM: 0.6331 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 101/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6032 - CustomAccuracy_OneNegSSIM: 0.6015 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 102/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6256 - CustomAccuracy_OneNegSSIM: 0.6271 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 103/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5996 - CustomAccuracy_OneNegSSIM: 0.6028 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 104/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6113 - CustomAccuracy_OneNegSSIM: 0.6072 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 105/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5948 - CustomAccuracy_OneNegSSIM: 0.5951 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 106/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5913 - CustomAccuracy_OneNegSSIM: 0.5902 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 107/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6063 - CustomAccuracy_OneNegSSIM: 0.6162 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 108/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5971 - CustomAccuracy_OneNegSSIM: 0.5958 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 109/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6185 - CustomAccuracy_OneNegSSIM: 0.6177 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 110/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6204 - CustomAccuracy_OneNegSSIM: 0.6223 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 111/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6147 - CustomAccuracy_OneNegSSIM: 0.6131 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 112/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5964 - CustomAccuracy_OneNegSSIM: 0.5955 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 113/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6172 - CustomAccuracy_OneNegSSIM: 0.6182 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 114/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6521 - CustomAccuracy_OneNegSSIM: 0.6607 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 115/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5867 - CustomAccuracy_OneNegSSIM: 0.5846 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 116/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6140 - CustomAccuracy_OneNegSSIM: 0.6213 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 117/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6446 - CustomAccuracy_OneNegSSIM: 0.6386 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 118/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5946 - CustomAccuracy_OneNegSSIM: 0.5992 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 119/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5999 - CustomAccuracy_OneNegSSIM: 0.6004 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 120/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5817 - CustomAccuracy_OneNegSSIM: 0.5822 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 121/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6336 - CustomAccuracy_OneNegSSIM: 0.6526 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 122/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5933 - CustomAccuracy_OneNegSSIM: 0.5941 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 123/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5971 - CustomAccuracy_OneNegSSIM: 0.6011 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 124/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6086 - CustomAccuracy_OneNegSSIM: 0.6089 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 125/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5989 - CustomAccuracy_OneNegSSIM: 0.5984 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 126/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5952 - CustomAccuracy_OneNegSSIM: 0.5955 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 127/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6530 - CustomAccuracy_OneNegSSIM: 0.6415 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 128/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6045 - CustomAccuracy_OneNegSSIM: 0.6016 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 129/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5755 - CustomAccuracy_OneNegSSIM: 0.5769 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 130/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6326 - CustomAccuracy_OneNegSSIM: 0.6454 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 131/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5986 - CustomAccuracy_OneNegSSIM: 0.5986 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 132/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6038 - CustomAccuracy_OneNegSSIM: 0.5995 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 133/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6101 - CustomAccuracy_OneNegSSIM: 0.6125 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 134/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6013 - CustomAccuracy_OneNegSSIM: 0.6073 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 135/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6011 - CustomAccuracy_OneNegSSIM: 0.6006 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 136/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5996 - CustomAccuracy_OneNegSSIM: 0.5994 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 137/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6379 - CustomAccuracy_OneNegSSIM: 0.6274 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 138/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5997 - CustomAccuracy_OneNegSSIM: 0.6101 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 139/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5941 - CustomAccuracy_OneNegSSIM: 0.5952 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 140/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5880 - CustomAccuracy_OneNegSSIM: 0.5905 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 141/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5967 - CustomAccuracy_OneNegSSIM: 0.5961 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 142/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5842 - CustomAccuracy_OneNegSSIM: 0.5770 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 143/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5858 - CustomAccuracy_OneNegSSIM: 0.5834 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 144/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6068 - CustomAccuracy_OneNegSSIM: 0.6097 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 145/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5965 - CustomAccuracy_OneNegSSIM: 0.5958 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 146/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5855 - CustomAccuracy_OneNegSSIM: 0.5872 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 147/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5927 - CustomAccuracy_OneNegSSIM: 0.5939 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 148/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5862 - CustomAccuracy_OneNegSSIM: 0.5876 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 149/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6633 - CustomAccuracy_OneNegSSIM: 0.6569 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 150/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5967 - CustomAccuracy_OneNegSSIM: 0.5979 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 151/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6141 - CustomAccuracy_OneNegSSIM: 0.6184 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 152/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6096 - CustomAccuracy_OneNegSSIM: 0.6119 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 153/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5884 - CustomAccuracy_OneNegSSIM: 0.5867 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 154/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6078 - CustomAccuracy_OneNegSSIM: 0.6102 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 155/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6488 - CustomAccuracy_OneNegSSIM: 0.6698 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 156/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5904 - CustomAccuracy_OneNegSSIM: 0.5929 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 157/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6121 - CustomAccuracy_OneNegSSIM: 0.6094 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 158/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5942 - CustomAccuracy_OneNegSSIM: 0.5934 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 159/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5879 - CustomAccuracy_OneNegSSIM: 0.5895 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 160/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5858 - CustomAccuracy_OneNegSSIM: 0.5834 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 161/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5932 - CustomAccuracy_OneNegSSIM: 0.5927 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 162/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6035 - CustomAccuracy_OneNegSSIM: 0.6169 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 163/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5945 - CustomAccuracy_OneNegSSIM: 0.5916 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 164/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5938 - CustomAccuracy_OneNegSSIM: 0.5934 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 165/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6034 - CustomAccuracy_OneNegSSIM: 0.6053 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 166/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6047 - CustomAccuracy_OneNegSSIM: 0.6083 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 167/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5970 - CustomAccuracy_OneNegSSIM: 0.5964 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 168/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5972 - CustomAccuracy_OneNegSSIM: 0.5969 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 169/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6317 - CustomAccuracy_OneNegSSIM: 0.6209 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 170/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5953 - CustomAccuracy_OneNegSSIM: 0.5972 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 171/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6062 - CustomAccuracy_OneNegSSIM: 0.6090 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 172/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6050 - CustomAccuracy_OneNegSSIM: 0.6023 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 173/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6444 - CustomAccuracy_OneNegSSIM: 0.6342 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 174/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5939 - CustomAccuracy_OneNegSSIM: 0.5961 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8409
# Epoch 175/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6075 - CustomAccuracy_OneNegSSIM: 0.6078 - accuracy: 0.7419 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8408
# Epoch 176/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5908 - CustomAccuracy_OneNegSSIM: 0.5929 - accuracy: 0.7418 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8408
# Epoch 177/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5985 - CustomAccuracy_OneNegSSIM: 0.6002 - accuracy: 0.7418 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8408
# Epoch 178/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5995 - CustomAccuracy_OneNegSSIM: 0.5998 - accuracy: 0.7418 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8408
# Epoch 179/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5993 - CustomAccuracy_OneNegSSIM: 0.5981 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8408
# Epoch 180/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6047 - CustomAccuracy_OneNegSSIM: 0.6140 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8408
# Epoch 181/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6165 - CustomAccuracy_OneNegSSIM: 0.6101 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8408
# Epoch 182/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6049 - CustomAccuracy_OneNegSSIM: 0.6035 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 183/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6105 - CustomAccuracy_OneNegSSIM: 0.6087 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 184/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6161 - CustomAccuracy_OneNegSSIM: 0.6137 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 185/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5972 - CustomAccuracy_OneNegSSIM: 0.5967 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 186/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6500 - CustomAccuracy_OneNegSSIM: 0.6374 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 187/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6379 - CustomAccuracy_OneNegSSIM: 0.6324 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 188/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6241 - CustomAccuracy_OneNegSSIM: 0.6151 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 189/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6048 - CustomAccuracy_OneNegSSIM: 0.6030 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 190/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5993 - CustomAccuracy_OneNegSSIM: 0.5985 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 191/1000
# 2/2 [==============================] - 2s 997ms/step - loss: 0.6250 - CustomAccuracy_OneNegSSIM: 0.6337 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 192/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6168 - CustomAccuracy_OneNegSSIM: 0.6237 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 193/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5923 - CustomAccuracy_OneNegSSIM: 0.5920 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8406
# Epoch 194/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5869 - CustomAccuracy_OneNegSSIM: 0.5836 - accuracy: 0.7416 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8406
# Epoch 195/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6703 - CustomAccuracy_OneNegSSIM: 0.6509 - accuracy: 0.7416 - val_loss: 0.5887 - val_CustomAccuracy_OneNegSSIM: 0.5887 - val_accuracy: 0.8406
# Epoch 196/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5871 - CustomAccuracy_OneNegSSIM: 0.5896 - accuracy: 0.7416 - val_loss: 0.5887 - val_CustomAccuracy_OneNegSSIM: 0.5887 - val_accuracy: 0.8406
# Epoch 197/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5906 - CustomAccuracy_OneNegSSIM: 0.5887 - accuracy: 0.7415 - val_loss: 0.5887 - val_CustomAccuracy_OneNegSSIM: 0.5887 - val_accuracy: 0.8404
# Epoch 198/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5962 - CustomAccuracy_OneNegSSIM: 0.5948 - accuracy: 0.7412 - val_loss: 0.5887 - val_CustomAccuracy_OneNegSSIM: 0.5887 - val_accuracy: 0.8406
# Epoch 199/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5953 - CustomAccuracy_OneNegSSIM: 0.5952 - accuracy: 0.7416 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 200/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6050 - CustomAccuracy_OneNegSSIM: 0.6036 - accuracy: 0.7416 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 201/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5857 - CustomAccuracy_OneNegSSIM: 0.5878 - accuracy: 0.7416 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 202/1000
# 2/2 [==============================] - 2s 992ms/step - loss: 0.5825 - CustomAccuracy_OneNegSSIM: 0.5843 - accuracy: 0.7417 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 203/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.6315 - CustomAccuracy_OneNegSSIM: 0.6253 - accuracy: 0.7416 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 204/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5961 - CustomAccuracy_OneNegSSIM: 0.5953 - accuracy: 0.7416 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8407
# Epoch 205/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5957 - CustomAccuracy_OneNegSSIM: 0.5970 - accuracy: 0.7416 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8406
# Epoch 206/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.5926 - CustomAccuracy_OneNegSSIM: 0.5960 - accuracy: 0.7416 - val_loss: 0.5888 - val_CustomAccuracy_OneNegSSIM: 0.5888 - val_accuracy: 0.8406
# Epoch 207/1000
# ...
# 2/2 [==============================] - 2s 1s/step - loss: 0.2887 - CustomAccuracy_OneNegSSIM: 0.2799 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 951/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2080 - CustomAccuracy_OneNegSSIM: 0.2108 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 952/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2013 - CustomAccuracy_OneNegSSIM: 0.2027 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 953/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2506 - CustomAccuracy_OneNegSSIM: 0.2588 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 954/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2103 - CustomAccuracy_OneNegSSIM: 0.2107 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 955/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2372 - CustomAccuracy_OneNegSSIM: 0.2330 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 956/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2058 - CustomAccuracy_OneNegSSIM: 0.2078 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 957/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2012 - CustomAccuracy_OneNegSSIM: 0.2062 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 958/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2161 - CustomAccuracy_OneNegSSIM: 0.2126 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 959/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2049 - CustomAccuracy_OneNegSSIM: 0.2064 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 960/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3317 - CustomAccuracy_OneNegSSIM: 0.3076 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 961/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2415 - CustomAccuracy_OneNegSSIM: 0.2345 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 962/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.1951 - CustomAccuracy_OneNegSSIM: 0.1871 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 963/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2568 - CustomAccuracy_OneNegSSIM: 0.2757 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 964/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2167 - CustomAccuracy_OneNegSSIM: 0.2121 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 965/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2241 - CustomAccuracy_OneNegSSIM: 0.2293 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 966/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2972 - CustomAccuracy_OneNegSSIM: 0.2792 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 967/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2141 - CustomAccuracy_OneNegSSIM: 0.2165 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 968/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2388 - CustomAccuracy_OneNegSSIM: 0.2499 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 969/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2133 - CustomAccuracy_OneNegSSIM: 0.2123 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 970/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2375 - CustomAccuracy_OneNegSSIM: 0.2398 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 971/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2325 - CustomAccuracy_OneNegSSIM: 0.2277 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 972/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2342 - CustomAccuracy_OneNegSSIM: 0.2275 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 973/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2288 - CustomAccuracy_OneNegSSIM: 0.2239 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 974/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2314 - CustomAccuracy_OneNegSSIM: 0.2367 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 975/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2164 - CustomAccuracy_OneNegSSIM: 0.2190 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 976/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2229 - CustomAccuracy_OneNegSSIM: 0.2303 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 977/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3005 - CustomAccuracy_OneNegSSIM: 0.2980 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 978/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2786 - CustomAccuracy_OneNegSSIM: 0.2643 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 979/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2202 - CustomAccuracy_OneNegSSIM: 0.2318 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 980/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2379 - CustomAccuracy_OneNegSSIM: 0.2488 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 981/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2211 - CustomAccuracy_OneNegSSIM: 0.2295 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 982/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2003 - CustomAccuracy_OneNegSSIM: 0.1951 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 983/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.1823 - CustomAccuracy_OneNegSSIM: 0.1878 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 984/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2830 - CustomAccuracy_OneNegSSIM: 0.3121 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 985/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2105 - CustomAccuracy_OneNegSSIM: 0.2085 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 986/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3122 - CustomAccuracy_OneNegSSIM: 0.2912 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 987/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2015 - CustomAccuracy_OneNegSSIM: 0.2025 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 988/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.1650 - CustomAccuracy_OneNegSSIM: 0.1745 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 989/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2159 - CustomAccuracy_OneNegSSIM: 0.2143 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 990/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2296 - CustomAccuracy_OneNegSSIM: 0.2323 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 991/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2025 - CustomAccuracy_OneNegSSIM: 0.2065 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 992/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.3207 - CustomAccuracy_OneNegSSIM: 0.2965 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 993/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2227 - CustomAccuracy_OneNegSSIM: 0.2204 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 994/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2515 - CustomAccuracy_OneNegSSIM: 0.2507 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 995/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2276 - CustomAccuracy_OneNegSSIM: 0.2266 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 996/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2597 - CustomAccuracy_OneNegSSIM: 0.2446 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 997/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2067 - CustomAccuracy_OneNegSSIM: 0.2058 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 998/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2640 - CustomAccuracy_OneNegSSIM: 0.2864 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 999/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.2157 - CustomAccuracy_OneNegSSIM: 0.2140 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# Epoch 1000/1000
# 2/2 [==============================] - 2s 1s/step - loss: 0.1961 - CustomAccuracy_OneNegSSIM: 0.1918 - accuracy: 0.2624 - val_loss: 0.1911 - val_CustomAccuracy_OneNegSSIM: 0.1911 - val_accuracy: 0.1696
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 13). These functions will not be directly callable after loading.
# WAIT! Saving Model...
#
# Training Finished
#    Model Log saved in      : /content/drive/MyDrive/COMP3362_Proj/ModelLog (Alex)/11-20 21:02:46 Model D (5 Fruits) (1000 Epochs) (0.002 lr) (Loss Function = OneNegSSIM)
#    Trained Model saved in  : /content/drive/MyDrive/COMP3362_Proj/TrainedModel (Alex)/11-20 21:02:46 Model D (5 Fruits) (1000 Epochs) (0.002 lr) (Loss Function = OneNegSSIM)
# bananas   (00) ------PSNR = 10.281186, SSIM = 0.689367, UIQM = -0.816261, UCIQE = 26.184492------
# avocados  (00) ------PSNR = 22.112113, SSIM = 0.970057, UIQM = -0.707092, UCIQE = 27.354631------
# acerolas  (00) ------PSNR = 17.318277, SSIM = 0.887451, UIQM = -0.441113, UCIQE = 22.992901------
# apples    (00) ------PSNR = 14.541506, SSIM = 0.789685, UIQM = -0.933274, UCIQE = 25.271947------
# apricots  (00) ------PSNR = 15.686819, SSIM = 0.838237, UIQM = -0.820727, UCIQE = 27.383532------
# bananas   (01) ------PSNR = 16.163915, SSIM = 0.925945, UIQM = -0.337503, UCIQE = 14.978277------
# avocados  (01) ------PSNR = 16.744272, SSIM = 0.905807, UIQM = -0.635432, UCIQE = 25.167593------
# acerolas  (01) ------PSNR = 19.173176, SSIM = 0.903466, UIQM = -0.756349, UCIQE = 21.100963------
# apples    (01) ------PSNR = 19.083599, SSIM = 0.919897, UIQM = -0.437365, UCIQE = 21.939403------
# apricots  (01) ------PSNR = 16.255448, SSIM = 0.916114, UIQM = -0.552798, UCIQE = 25.201212------
# bananas   (02) ------PSNR = 15.547507, SSIM = 0.931190, UIQM = -0.337752, UCIQE = 21.832521------
# avocados  (02) ------PSNR = 19.003618, SSIM = 0.947923, UIQM = -0.647446, UCIQE = 27.083738------
# acerolas  (02) ------PSNR = 14.680482, SSIM = 0.762257, UIQM = -0.799083, UCIQE = 27.282317------
# apples    (02) ------PSNR = 14.576508, SSIM = 0.879888, UIQM = -0.497651, UCIQE = 19.654415------
# apricots  (02) ------PSNR = 10.217870, SSIM = 0.704407, UIQM = -0.775325, UCIQE = 20.351994------
# -------------------------------------------------------------------------------------------------
# Average        ------PSNR = 16.092420, SSIM = 0.864779, UIQM = -0.633011, UCIQE = 23.585329------
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Number of labels: 5
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Predicted value range:
#   L  : [0.253021240234375, 81.62376403808594]
#   AB : [-1.0, 1.0]
#   LAB: [-1.0, 81.62376403808594]
#   RGB: [0.0, 0.8065099120140076]
# Original value range:
#   LAB: [-30.38117218017578, 81.62376403808594]
#   RGB: [0.0, 1.0]
#   Gry: [0.00361607875674963, 0.7749125957489014]
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Originial LAB Image 0 to 1
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Predicted LAB Image 0 to 1
# Original LAB 3D Graph
# (256, 256, 3)
# (65536, 3)
# Range: [-30.38117218017578, 81.62376403808594]
# Predicted LAB 3D Graph
# (256, 256, 3)
# (65536, 3)
# Range: [-1.0, 81.62376403808594]
# Original LAB 2D Graph
# (256, 256, 3)
# (65536, 3)
# Range: [-30.38117218017578, 81.62376403808594]
# Predicted LAB 2D Graph
# (256, 256, 3)
# (65536, 3)
# Range: [-1.0, 81.62376403808594]
